# %% [markdown]
# # Analyzing the Linear Relaxation

# %%
from _evaluation import (  # the code has been moved to a separate file
    get_sample,
    n,
    samples,
)

# %% [markdown]
# ## Getting a sample solution
#
# The following code will create a random instance and solve
#
# 1. The linear relaxation with `>=2` subtour elimination constraints
# 2. The linear relaxation with `>=1` subtour elimination constraints
# 3. The integer programming problem to get an optimal solution
#
# It will plot the solutions for you to compare and save the results in the `samples` list.
#
# In the plots, the red lines represent fractional edges, i.e., edges with a value between 0 and 1.
# The green lines represent edges where the linear relaxation and the optimal solution agree.
# The title will show the objective value of the solution or the overlap between the linear relaxation and the optimal solution.

# %%
# Run me to get a sample on linear relaxation and integral solution
get_sample()
print(f"There are now {len(samples)} samples")
# Out:
# Solving the linear relaxation with k=2
# Set parameter LogToConsole to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 200 rows, 19900 columns and 39800 nonzeros (Min)
# Model fingerprint: 0x93dc09e8
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Presolve time: 0.01s
# Presolved: 200 rows, 19900 columns, 39800 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.990e+04
#  Factor NZ  : 2.010e+04 (roughly 8 MB of memory)
#  Factor Ops : 2.687e+06 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.02 seconds (0.01 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      284    1.0333000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 284 iterations and 0.02 seconds (0.02 work units)
# Optimal objective  1.033300000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 227 rows, 19900 columns and 72856 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0333000e+04   5.400000e+01   0.000000e+00      0s
#       59    1.0669500e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 59 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.066950000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 233 rows, 19900 columns and 93652 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0669500e+04   1.200000e+01   0.000000e+00      0s
#       17    1.0716000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 17 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.071600000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 237 rows, 19900 columns and 119266 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0716000e+04   8.000000e+00   0.000000e+00      0s
#        9    1.0724500e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.072450000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 239 rows, 19900 columns and 120448 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0724500e+04   4.000000e+00   0.000000e+00      0s
#        5    1.0736500e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.073650000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 241 rows, 19900 columns and 122016 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0736500e+04   4.000000e+00   0.000000e+00      0s
#        4    1.0744000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 4 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.074400000e+04
# Solving the integral problem
# Set parameter LogToConsole to value 1
# Set parameter TimeLimit to value 30
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0.001
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  30
# MIPGap  0.001
# LazyConstraints  1
#
# Optimize a model with 200 rows, 19900 columns and 39800 nonzeros (Min)
# Model fingerprint: 0xed5ac4c4
# Model has 19900 linear objective coefficients
# Variable types: 0 continuous, 19900 integer (19900 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Presolve time: 0.02s
# Presolved: 200 rows, 19900 columns, 39800 nonzeros
# Variable types: 0 continuous, 19900 integer (19900 binary)
#
# Root relaxation: objective 1.033300e+04, 304 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 10333.0000    0   24          - 10333.0000      -     -    0s
#      0     0 10667.5000    0   42          - 10667.5000      -     -    0s
#      0     0 10722.0000    0   48          - 10722.0000      -     -    0s
#      0     0 10733.6667    0   80          - 10733.6667      -     -    0s
#      0     0 10780.0833    0   57          - 10780.0833      -     -    0s
#      0     0 10782.3333    0   57          - 10782.3333      -     -    0s
#      0     0 10782.3333    0   55          - 10782.3333      -     -    0s
#      0     2 10782.3333    0   55          - 10782.3333      -     -    0s
# H  583   572                    12900.000000 10787.0833  16.4%   8.0    1s
# * 1053   967              93    11260.000000 10787.3333  4.20%   7.5    2s
# * 1352   929              54    11108.000000 10787.3333  2.89%   7.5    2s
# H 1628  1091                    11082.000000 10791.5000  2.62%   7.6    3s
# H 1628  1036                    11066.000000 10791.5000  2.48%   7.6    3s
# H 1632   986                    11062.000000 10880.0833  1.64%   7.6    3s
# H 1639   942                    11058.000000 10901.8667  1.41%   8.0    4s
# H 1639   895                    11001.000000 10901.8667  0.90%   8.0    4s
# H 1639   850                    10999.000000 10901.8667  0.88%   8.0    4s
# H 1639   807                    10960.000000 10901.8667  0.53%   8.0    4s
# H 1639   767                    10954.000000 10901.8667  0.48%   8.0    4s
# H 1639   728                    10948.000000 10901.8667  0.42%   8.0    4s
# H 1639   692                    10945.000000 10901.8667  0.39%   8.0    4s
# H 1639   657                    10938.000000 10901.8667  0.33%   8.0    4s
# H 1639   624                    10932.000000 10901.8667  0.28%   8.0    4s
# H 1669   613                    10931.000000 10917.6844  0.12%   8.3    4s
#   1692   629 10919.4819   22  159 10931.0000 10919.4819  0.11%   8.8    5s
#
# Cutting planes:
#   Gomory: 20
#   Cover: 1
#   Clique: 3
#   Flow cover: 7
#   GUB cover: 2
#   Zero half: 33
#
# Explored 1695 nodes (16185 simplex iterations) in 5.07 seconds (6.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 10931 10932 10938 ... 11058
#
# Optimal solution found (tolerance 1.00e-03)
# Best objective 1.093100000000e+04, best bound 1.092100000000e+04, gap 0.0915%
#
# User-callback calls 5437, time in user-callback 1.05 sec
# Solving the linear relaxation with k=1
# Set parameter LogToConsole to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 200 rows, 19900 columns and 39800 nonzeros (Min)
# Model fingerprint: 0x93dc09e8
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Presolve time: 0.01s
# Presolved: 200 rows, 19900 columns, 39800 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.990e+04
#  Factor NZ  : 2.010e+04 (roughly 8 MB of memory)
#  Factor Ops : 2.687e+06 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.02 seconds (0.01 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      284    1.0333000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 284 iterations and 0.02 seconds (0.02 work units)
# Optimal objective  1.033300000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 227 rows, 19900 columns and 72856 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0333000e+04   2.700000e+01   0.000000e+00      0s
#       48    1.0489000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 48 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.048900000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 231 rows, 19900 columns and 86342 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0489000e+04   4.000000e+00   0.000000e+00      0s
#        4    1.0502500e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 4 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.050250000e+04
# Objective value: 10931, Linear relaxation k=2 value: 10744.0, Overlap: 175/200
# Objective value: 10931, Linear relaxation k=1 value: 10502.5, Overlap: 171/200
# There are now 25 samples

# %%
for i, (objective_value, linear_relaxation_value, overlap) in enumerate(samples):
    print(
        f"Sample {i}: Objective value: {objective_value}, Linear relaxation value (>=2): {linear_relaxation_value}, Overlap: {overlap}/{n}"
    )
# Out:
# Sample 0: Objective value: 11113, Linear relaxation value (>=2): 10925.0, Overlap: 178/200
# Sample 1: Objective value: 10739, Linear relaxation value (>=2): 10590.75, Overlap: 181/200
# Sample 2: Objective value: 10287, Linear relaxation value (>=2): 10140.5, Overlap: 179/200
# Sample 3: Objective value: 11003, Linear relaxation value (>=2): 10768.75, Overlap: 163/200
# Sample 4: Objective value: 10918, Linear relaxation value (>=2): 10808.75, Overlap: 184/200
# Sample 5: Objective value: 10331, Linear relaxation value (>=2): 10237.5, Overlap: 177/200
